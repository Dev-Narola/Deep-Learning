# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv('datasets/placement.csv')
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(data=df, x="cgpa", y = "resume_score", hue="placed")
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.linear_model import Perceptron

pt = Perceptron()
pt.fit(X, y)
pt.coef_, pt.intercept_
# Out:
# (array([[ 40.26, -36.  ]]), array([-25.]))

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf = pt)
# Out:
# d:\Main_Files\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred=pt.predict(X), y_true=y)
# Out:
# 0.75
